# %%
import pandas as pd

# %%
#주민등록 인구 데이터읽어오기
df1=pd.read_csv("C:/Users/owner/Desktop/02.team_project_data/서울시_주민등록인구/서울시주민등록인구2019통계.txt",sep= "\t")
df2=pd.read_csv("C:/Users/owner/Desktop/02.team_project_data/서울시_주민등록인구/서울시주민등록인구2020통계.txt",sep= "\t")
# Out:
#       기간   자치구         세대          인구       인구.1       인구.2       인구.3  \
# 0     기간   자치구         세대          합계         합계         합계        한국인
# 1     기간   자치구         세대           계         남자         여자          계
# 2   2019    합계  4,327,605  10,010,983  4,877,725  5,133,258  9,729,107
# 3   2019   종로구     73,947     161,869     78,215     83,654    151,290
# 4   2019    중구     62,739     136,488     66,823     69,665    126,171
# 5   2019   용산구    110,126     245,185    119,599    125,586    228,670
# 6   2019   성동구    135,838     308,979    150,861    158,118    300,889
# 7   2019   광진구    164,428     366,972    176,917    190,055    351,350
# 8   2019  동대문구    164,191     363,023    178,490    184,533    346,194
# 9   2019   중랑구    181,579     402,024    199,006    203,018    397,015
# 10  2019   성북구    192,592     454,744    219,099    235,645    442,650
# 11  2019   강북구    144,277     317,695    154,638    163,057    313,954
# ...

# %%
columns=["기간","자치구","세대","합계","남자합계","여자합계","한국인합계","한국인남자","한국인여자","외국인합계","외국인남자","외국인여자","세대당인구","65세이상고령자"]
columns
# Out:
# ['기간',
#  '자치구',
#  '세대',
#  '합계',
#  '남자합계',
#  '여자합계',
#  '한국인합계',
#  '한국인남자',
#  '한국인여자',
#  '외국인합계',
#  '외국인남자',
#  '외국인여자',
#  '세대당인구',
#  '65세이상고령자']

# %%
import numpy as np

# %%
df1.columns=columns
df2.columns=columns

# %%
people_num=pd.concat([df1,df2],ignore_index=True)

# %%
people_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        56 non-null     object
#  1   자치구       56 non-null     object
#  2   세대        56 non-null     object
#  3   합계        56 non-null     object
#  4   남자합계      56 non-null     object
#  5   여자합계      56 non-null     object
#  6   한국인합계     56 non-null     object
#  7   한국인남자     56 non-null     object
#  8   한국인여자     56 non-null     object
#  9   외국인합계     56 non-null     object
#  10  외국인남자     56 non-null     object
#  11  외국인여자     56 non-null     object
#  12  세대당인구     56 non-null     object
#  13  65세이상고령자  56 non-null     object
# dtypes: object(14)
# memory usage: 6.2+ KB

# %%
people_num.to_csv("people_data.xlsx")

# %%
people_num.columns
# Out:
# Index(['기간', '자치구', '세대', '합계', '남자합계', '여자합계', '한국인합계', '한국인남자', '한국인여자',
#        '외국인합계', '외국인남자', '외국인여자', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
# people_num2=people_num[['기간','자치구','세대','합계','남자합계','여자합계','한국인합계','한국인남자','한국인여자','외국인합계','외국인남자','외국인여자','세대당인구','65세이상고령자']]
# people_num2.columns

# %%
people_num2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        56 non-null     object
#  1   자치구       56 non-null     object
#  2   세대        56 non-null     object
#  3   합계        56 non-null     object
#  4   남자합계      56 non-null     object
#  5   여자합계      56 non-null     object
#  6   한국인합계     56 non-null     object
#  7   한국인남자     56 non-null     object
#  8   한국인여자     56 non-null     object
#  9   외국인합계     56 non-null     object
#  10  외국인남자     56 non-null     object
#  11  외국인여자     56 non-null     object
#  12  세대당인구     56 non-null     object
#  13  65세이상고령자  56 non-null     object
# dtypes: object(14)
# memory usage: 6.2+ KB

# %%
people_num2=people_num2.sort_values(['기간','자치구','세대','합계','남자합계','여자합계','한국인합계','한국인남자','한국인여자','외국인합계','외국인남자','외국인여자','세대당인구','65세이상고령자'])
people_num2.info()
people_num2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 25 to 28
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        56 non-null     object
#  1   자치구       56 non-null     object
#  2   세대        56 non-null     object
#  3   합계        56 non-null     object
#  4   남자합계      56 non-null     object
#  5   여자합계      56 non-null     object
#  6   한국인합계     56 non-null     object
#  7   한국인남자     56 non-null     object
#  8   한국인여자     56 non-null     object
#  9   외국인합계     56 non-null     object
#  10  외국인남자     56 non-null     object
#  11  외국인여자     56 non-null     object
#  12  세대당인구     56 non-null     object
#  13  65세이상고령자  56 non-null     object
# dtypes: object(14)
# memory usage: 6.6+ KB
#       기간   자치구         세대          합계       남자합계       여자합계      한국인합계  \
# 25  2019   강남구    232,981     550,209    263,345    286,864    545,169
# ...

# %%
people_num2.to_csv("people_data2.xlsx")

# %%
year_2019=people_num2.loc[people_num2['기간']==2019]

# %%
people=year_2019['합계'].value_counts()

# %%
people.to_excel('people.xlsx')

# %%
year_2019.columns
# Out:
# Index(['기간', '자치구', '세대', '합계', '남자합계', '여자합계', '한국인합계', '한국인남자', '한국인여자',
#        '외국인합계', '외국인남자', '외국인여자', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
people_num2.to_csv("people_data5.csv",sep='\t',encoding="utf-8",index=None)
